# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel
import itertools

file_path = "/content/drive/My Drive/Colab Notebooks/14-Indices (2).txt"

W = {"Lay Summary" : {}, "Technical Summary": {} }
S = {"Lay Summary" : {}, "Technical Summary": {} }
VP = {"Lay Summary" : {}, "Technical Summary": {} }
C = {"Lay Summary" : {}, "Technical Summary": {} }
T = {"Lay Summary" : {}, "Technical Summary": {} }
DC = {"Lay Summary" : {}, "Technical Summary": {} }
CT = {"Lay Summary" : {}, "Technical Summary": {} }
CP = {"Lay Summary" : {}, "Technical Summary": {} }
CN = {"Lay Summary" : {}, "Technical Summary": {} }
MLS = {"Lay Summary" : {}, "Technical Summary": {} }
MLT = {"Lay Summary" : {}, "Technical Summary": {} }
MLC = {"Lay Summary" : {}, "Technical Summary": {} }
C_S = {"Lay Summary" : {}, "Technical Summary": {} }
VP_T = {"Lay Summary" : {}, "Technical Summary": {} }
C_T = {"Lay Summary" : {}, "Technical Summary": {} }
DC_C = {"Lay Summary" : {}, "Technical Summary": {} }
DC_T = {"Lay Summary" : {}, "Technical Summary": {} }
T_S = {"Lay Summary" : {}, "Technical Summary": {} }
CT_T = {"Lay Summary" : {}, "Technical Summary": {} }
CP_T = {"Lay Summary" : {}, "Technical Summary": {} }
CP_C = {"Lay Summary" : {}, "Technical Summary": {} }
CN_T = {"Lay Summary" : {}, "Technical Summary": {} }
CN_C = {"Lay Summary" : {}, "Technical Summary": {} }

subjectLabels = {}

MasterDictionary2 = {"W" : W, "S" : S, "VP": VP, "C": C, "T": T, "DC" : DC, "CT" : CT, "CP" :CP, "CN" :CN, "MLS" : MLS, "MLT" : MLT, "MLC" : MLC, "C_S" : C_S, "VP_T" : VP_T, "C_T" : C_T, "DC_C" : DC_C, "DC_T" : DC_T, "T_S" : T_S, "CT_T" : CT_T, "CP_T" : CP_T, "CP_C" : CP_C, "CN_T" : CN_T, "CN_C" : CN_C}
Subjects = {}

lineNum = 0
laySummaryCount = 0
techSummaryCount = 0

with open(file_path, "r") as file:

    for line in file:

        #Document all the subjects of the summaries
        lineNum += 1
        if lineNum % 3 == 1:
          subject = line.strip().lower()
          if subject in Subjects.keys():
            Subjects[subject] += 1
          else:
            Subjects[subject] = 1
        else:
          # Remove trailing newline and whitespace
          preValues = [val.strip() for val in line.strip().split(",")]
          values = []
          for value in preValues:
            values.append(float(value))

          if lineNum % 3 == 2:

            laySummaryCount += 1
            subjectLabels[laySummaryCount] = subject.strip().lower()

          else:

            techSummaryCount += 1

          for value in values:


            if lineNum % 3 == 2:


              W["Lay Summary"][laySummaryCount] = values[0]
              S["Lay Summary"][laySummaryCount] = values[1]
              VP["Lay Summary"][laySummaryCount] = values[2]
              C["Lay Summary"][laySummaryCount] = values[3]
              T["Lay Summary"][laySummaryCount] = values[4]
              DC["Lay Summary"][laySummaryCount] = values[5]
              CT["Lay Summary"][laySummaryCount] = values[6]
              CP["Lay Summary"][laySummaryCount] = values[7]
              CN["Lay Summary"][laySummaryCount] = values[8]
              MLS["Lay Summary"][laySummaryCount] = values[9]
              MLT["Lay Summary"][laySummaryCount] = values[10]
              MLC["Lay Summary"][laySummaryCount] = values[11]
              C_S["Lay Summary"][laySummaryCount] = values[12]
              VP_T["Lay Summary"][laySummaryCount] = values[13]
              C_T["Lay Summary"][laySummaryCount] = values[14]
              DC_C["Lay Summary"][laySummaryCount] = values[15]
              DC_T["Lay Summary"][laySummaryCount] = values[16]
              T_S["Lay Summary"][laySummaryCount] = values[17]
              CT_T["Lay Summary"][laySummaryCount] = values[18]
              CP_T["Lay Summary"][laySummaryCount] = values[19]
              CP_C["Lay Summary"][laySummaryCount] = values[20]
              CN_T["Lay Summary"][laySummaryCount] = values[21]
              CN_C["Lay Summary"][laySummaryCount] = values[22]
            else:
              W["Technical Summary"][techSummaryCount] = values[0]
              S["Technical Summary"][techSummaryCount] = values[1]
              VP["Technical Summary"][techSummaryCount] = values[2]
              C["Technical Summary"][techSummaryCount] = values[3]
              T["Technical Summary"][techSummaryCount] = values[4]
              DC["Technical Summary"][techSummaryCount] = values[5]
              CT["Technical Summary"][techSummaryCount] = values[6]
              CP["Technical Summary"][techSummaryCount] = values[7]
              CN["Technical Summary"][techSummaryCount] = values[8]
              MLS["Technical Summary"][techSummaryCount] = values[9]
              MLT["Technical Summary"][techSummaryCount] = values[10]
              MLC["Technical Summary"][techSummaryCount] = values[11]
              C_S["Technical Summary"][techSummaryCount] = values[12]
              VP_T["Technical Summary"][techSummaryCount] = values[13]
              C_T["Technical Summary"][techSummaryCount] = values[14]
              DC_C["Technical Summary"][techSummaryCount] = values[15]
              DC_T["Technical Summary"][techSummaryCount] = values[16]
              T_S["Technical Summary"][techSummaryCount] = values[17]
              CT_T["Technical Summary"][techSummaryCount] = values[18]
              CP_T["Technical Summary"][techSummaryCount] = values[19]
              CP_C["Technical Summary"][techSummaryCount] = values[20]
              CN_T["Technical Summary"][techSummaryCount] = values[21]
              CN_C["Technical Summary"][techSummaryCount] = values[22]


physicalSciences = ['environmental sciences', 'earth, atmospheric, and planetary sciences', 'applied physical sciences', 'computer sciences','applied mathematics','engineering','chemistry','statistics','sustainability science','physics','astronomy']
biologicalSciences = ['biophysics and computational biology','immunology and inflammation','neuroscience', 'genetics', 'ecology', 'medical sciences','evolution','plant biology','agricultural sciences','applied biological sciences','biochemistry','developmental biology','systems biology','microbiology','pharmacology','cell biology','physiology','population biology']
socialSciences = ['economic sciences','psychological and cognitive sciences','demography','political sciences','social sciences','anthropology','']

umbrellas = {'physicalSciences':physicalSciences,'biologicalSciences':biologicalSciences,'socialSciences': socialSciences}

physCount = 0
bioCount = 0
socCount = 0

index = 0

for index in subjectLabels.keys():

  subject = subjectLabels[index]

  if subject in physicalSciences:

    physCount += 1

  elif subject in biologicalSciences:

    bioCount += 1

  elif subject in socialSciences:

    socCount += 1

bioQ1Q2Mean = {"W":{'q1':0,'q3':0, 'median':0}, "S":{'q1':0,'q3':0, 'median':0}, "VP":{'q1':0,'q3':0, 'median':0}, "C":{'q1':0,'q3':0, 'median':0}, "T":{'q1':0,'q3':0, 'median':0}, "DC":{'q1':0,'q3':0, 'median':0}, "CT":{'q1':0,'q3':0, 'median':0}, "CP":{'q1':0,'q3':0, 'median':0}, "CN":{'q1':0,'q3':0, 'median':0},
    "MLS":{'q1':0,'q3':0, 'median':0}, "MLT":{'q1':0,'q3':0, 'median':0}, "MLC":{'q1':0,'q3':0, 'median':0}, "C_S":{'q1':0,'q3':0, 'median':0}, "VP_T":{'q1':0,'q3':0, 'median':0}, "C_T":{'q1':0,'q3':0, 'median':0}, "DC_C":{'q1':0,'q3':0, 'median':0}, "DC_T":{'q1':0,'q3':0, 'median':0},
    "T_S":{'q1':0,'q3':0, 'median':0}, "CT_T":{'q1':0,'q3':0, 'median':0}, "CP_T":{'q1':0,'q3':0, 'median':0}, "CP_C":{'q1':0,'q3':0, 'median':0}, "CN_T":{'q1':0,'q3':0, 'median':0}, "CN_C":{'q1':0,'q3':0, 'median':0}}
physQ1Q2Mean = {"W":{'q1':0,'q3':0, 'median':0}, "S":{'q1':0,'q3':0, 'median':0}, "VP":{'q1':0,'q3':0, 'median':0}, "C":{'q1':0,'q3':0, 'median':0}, "T":{'q1':0,'q3':0, 'median':0}, "DC":{'q1':0,'q3':0, 'median':0}, "CT":{'q1':0,'q3':0, 'median':0}, "CP":{'q1':0,'q3':0, 'median':0}, "CN":{'q1':0,'q3':0, 'median':0},
    "MLS":{'q1':0,'q3':0, 'median':0}, "MLT":{'q1':0,'q3':0, 'median':0}, "MLC":{'q1':0,'q3':0, 'median':0}, "C_S":{'q1':0,'q3':0, 'median':0}, "VP_T":{'q1':0,'q3':0, 'median':0}, "C_T":{'q1':0,'q3':0, 'median':0}, "DC_C":{'q1':0,'q3':0, 'median':0}, "DC_T":{'q1':0,'q3':0, 'median':0},
    "T_S":{'q1':0,'q3':0, 'median':0}, "CT_T":{'q1':0,'q3':0, 'median':0}, "CP_T":{'q1':0,'q3':0, 'median':0}, "CP_C":{'q1':0,'q3':0, 'median':0}, "CN_T":{'q1':0,'q3':0, 'median':0}, "CN_C":{'q1':0,'q3':0, 'median':0}}
sociQ1Q2Mean = {"W":{'q1':0,'q3':0, 'median':0}, "S":{'q1':0,'q3':0, 'median':0}, "VP":{'q1':0,'q3':0, 'median':0}, "C":{'q1':0,'q3':0, 'median':0}, "T":{'q1':0,'q3':0, 'median':0}, "DC":{'q1':0,'q3':0, 'median':0}, "CT":{'q1':0,'q3':0, 'median':0}, "CP":{'q1':0,'q3':0, 'median':0}, "CN":{'q1':0,'q3':0, 'median':0},
    "MLS":{'q1':0,'q3':0, 'median':0}, "MLT":{'q1':0,'q3':0, 'median':0}, "MLC":{'q1':0,'q3':0, 'median':0}, "C_S":{'q1':0,'q3':0, 'median':0}, "VP_T":{'q1':0,'q3':0, 'median':0}, "C_T":{'q1':0,'q3':0, 'median':0}, "DC_C":{'q1':0,'q3':0, 'median':0}, "DC_T":{'q1':0,'q3':0, 'median':0},
    "T_S":{'q1':0,'q3':0, 'median':0}, "CT_T":{'q1':0,'q3':0, 'median':0}, "CP_T":{'q1':0,'q3':0, 'median':0}, "CP_C":{'q1':0,'q3':0, 'median':0}, "CN_T":{'q1':0,'q3':0, 'median':0}, "CN_C":{'q1':0,'q3':0, 'median':0}}


for key in MasterDictionary2.keys():
  bio = []
  phys = []
  soci = []

  for i in range(1,301):

    if subjectLabels[i] in physicalSciences:
      phys.append(MasterDictionary2[key]["Technical Summary"][i])
    elif subjectLabels[i] in biologicalSciences:
      bio.append(MasterDictionary2[key]["Technical Summary"][i])
    elif subjectLabels[i] in socialSciences:
      soci.append(MasterDictionary2[key]["Technical Summary"][i])

  bioQ1Q2Mean[key]['q1'] = np.percentile(np.fromiter(bio, dtype=float),25)
  bioQ1Q2Mean[key]['q3'] = np.percentile(np.fromiter(bio, dtype=float),75)
  bioQ1Q2Mean[key]['mean'] = np.median(np.fromiter(bio,dtype=float))

  physQ1Q2Mean[key]['q1'] = np.percentile(np.fromiter(phys, dtype=float),25)
  physQ1Q2Mean[key]['q3'] = np.percentile(np.fromiter(phys, dtype=float),75)
  physQ1Q2Mean[key]['median'] = np.median(np.fromiter(phys,dtype=float))

  sociQ1Q2Mean[key]['q1'] = np.percentile(np.fromiter(soci, dtype=float),25)
  sociQ1Q2Mean[key]['q3'] = np.percentile(np.fromiter(soci, dtype=float),75)
  sociQ1Q2Mean[key]['median'] = np.median(np.fromiter(soci,dtype=float))

Measures = [W,S,VP,C,T,DC,CT,CP,CN,MLS,MLT,MLC,C_S,VP_T,C_T,DC_C,DC_T,T_S,CT_T,CP_T,CP_C,CN_T,CN_C]

measure_names = [
    "W", "S", "VP", "C", "T", "DC", "CT", "CP", "CN",
    "MLS", "MLT", "MLC", "C_S", "VP_T", "C_T", "DC_C", "DC_T",
    "T_S", "CT_T", "CP_T", "CP_C", "CN_T", "CN_C"
]


results3 = {}
for pair in itertools.combinations(umbrellas.keys(),2):
  results3[pair] = {}

for pair in itertools.combinations(umbrellas.keys(), 2):

  subjOne = pair[0]
  subjTwo = pair[1]

  for name, measure in zip(measure_names, Measures):

    subOneValues = []
    subTwoValues = []


    for i in range(1,300):

      if subjectLabels[i] in umbrellas[subjOne]:
        subOneValues.append(measure["Lay Summary"][i])

      elif subjectLabels[i] in umbrellas[subjTwo]:

        subTwoValues.append(measure["Lay Summary"][i])

    desiredLength = min(len(subTwoValues), len(subOneValues))

    subOneValues = subOneValues[:desiredLength]
    subTwoValues = subTwoValues[:desiredLength]

    t_stat, p_val = ttest_rel(subOneValues, subTwoValues)

    results3[pair][name] = {'t': t_stat, 'p': p_val}

    print(f"{name} for {pair}")

    plt.hist(subOneValues, bins = 30, color = 'skyblue', alpha = 0.5, label = "lay")

    plt.hist(subTwoValues, bins = 30, color = 'red', alpha = 0.5, label = "tech")

    plt.show()

    plt.ecdf(subOneValues, color = 'skyblue', alpha = 0.5, label = "lay")

    plt.ecdf(subTwoValues, color = 'red', alpha = 0.5, label = "tech")

    plt.show()

for pair in results3.keys():

  for measure in measure_names:
    if results3[pair][measure]['p']<0.05:
      print(f"significant different in {measure} for {pair}, t-value = {results3[pair][measure]['t']}, p-value = {results3[pair][measure]['p']} ")
    elif results3[pair][measure]['p']<0.1:
      print(f"weak difference in {measure} for {pair}, t-value = {results3[pair][measure]['t']}, p-value = {results3[pair][measure]['p']} ")
    elif results3[pair][measure]['p']>=0.1:
      print(f"no significant difference in {measure} for {pair}, t-value = {results3[pair][measure]['t']}, p-value = {results3[pair][measure]['p']} ")

#print(bioQ1Q2Mean)
#print(physQ1Q2Mean)
#print(sociQ1Q2Mean)
#print(results3)
# Out:
# Mounted at /content/drive
# W for ('physicalSciences', 'biologicalSciences')
# S for ('physicalSciences', 'biologicalSciences')
# VP for ('physicalSciences', 'biologicalSciences')
# C for ('physicalSciences', 'biologicalSciences')
# T for ('physicalSciences', 'biologicalSciences')
# DC for ('physicalSciences', 'biologicalSciences')
# CT for ('physicalSciences', 'biologicalSciences')
# CP for ('physicalSciences', 'biologicalSciences')
# CN for ('physicalSciences', 'biologicalSciences')
# MLS for ('physicalSciences', 'biologicalSciences')
# MLT for ('physicalSciences', 'biologicalSciences')
# MLC for ('physicalSciences', 'biologicalSciences')
# C_S for ('physicalSciences', 'biologicalSciences')
# VP_T for ('physicalSciences', 'biologicalSciences')
# C_T for ('physicalSciences', 'biologicalSciences')
# DC_C for ('physicalSciences', 'biologicalSciences')
# DC_T for ('physicalSciences', 'biologicalSciences')
# T_S for ('physicalSciences', 'biologicalSciences')
# CT_T for ('physicalSciences', 'biologicalSciences')
# CP_T for ('physicalSciences', 'biologicalSciences')
# CP_C for ('physicalSciences', 'biologicalSciences')
# CN_T for ('physicalSciences', 'biologicalSciences')
# CN_C for ('physicalSciences', 'biologicalSciences')
# W for ('physicalSciences', 'socialSciences')
# S for ('physicalSciences', 'socialSciences')
# VP for ('physicalSciences', 'socialSciences')
# C for ('physicalSciences', 'socialSciences')
# T for ('physicalSciences', 'socialSciences')
# DC for ('physicalSciences', 'socialSciences')
# CT for ('physicalSciences', 'socialSciences')
# CP for ('physicalSciences', 'socialSciences')
# CN for ('physicalSciences', 'socialSciences')
# MLS for ('physicalSciences', 'socialSciences')
# MLT for ('physicalSciences', 'socialSciences')
# MLC for ('physicalSciences', 'socialSciences')
# C_S for ('physicalSciences', 'socialSciences')
# VP_T for ('physicalSciences', 'socialSciences')
# C_T for ('physicalSciences', 'socialSciences')
# DC_C for ('physicalSciences', 'socialSciences')
# DC_T for ('physicalSciences', 'socialSciences')
# T_S for ('physicalSciences', 'socialSciences')
# CT_T for ('physicalSciences', 'socialSciences')
# CP_T for ('physicalSciences', 'socialSciences')
# CP_C for ('physicalSciences', 'socialSciences')
# CN_T for ('physicalSciences', 'socialSciences')
# CN_C for ('physicalSciences', 'socialSciences')
# W for ('biologicalSciences', 'socialSciences')
# S for ('biologicalSciences', 'socialSciences')
# VP for ('biologicalSciences', 'socialSciences')
# C for ('biologicalSciences', 'socialSciences')
# T for ('biologicalSciences', 'socialSciences')
# DC for ('biologicalSciences', 'socialSciences')
# CT for ('biologicalSciences', 'socialSciences')
# CP for ('biologicalSciences', 'socialSciences')
# CN for ('biologicalSciences', 'socialSciences')
# MLS for ('biologicalSciences', 'socialSciences')
# MLT for ('biologicalSciences', 'socialSciences')
# MLC for ('biologicalSciences', 'socialSciences')
# C_S for ('biologicalSciences', 'socialSciences')
# VP_T for ('biologicalSciences', 'socialSciences')
# C_T for ('biologicalSciences', 'socialSciences')
# DC_C for ('biologicalSciences', 'socialSciences')
# DC_T for ('biologicalSciences', 'socialSciences')
# T_S for ('biologicalSciences', 'socialSciences')
# CT_T for ('biologicalSciences', 'socialSciences')
# CP_T for ('biologicalSciences', 'socialSciences')
# CP_C for ('biologicalSciences', 'socialSciences')
# CN_T for ('biologicalSciences', 'socialSciences')
# CN_C for ('biologicalSciences', 'socialSciences')
# no significant difference in W for ('physicalSciences', 'biologicalSciences'), t-value = 0.4245530073117325, p-value = 0.6723464820766671
# weak difference in S for ('physicalSciences', 'biologicalSciences'), t-value = -1.7455632132852164, p-value = 0.08487583594093757
# no significant difference in VP for ('physicalSciences', 'biologicalSciences'), t-value = -1.0812399020510517, p-value = 0.2829651829299608
# no significant difference in C for ('physicalSciences', 'biologicalSciences'), t-value = -1.5070008186245956, p-value = 0.1359023201263473
# no significant difference in T for ('physicalSciences', 'biologicalSciences'), t-value = -1.4389241534782935, p-value = 0.15422468631525021
# no significant difference in DC for ('physicalSciences', 'biologicalSciences'), t-value = -1.1464584591591294, p-value = 0.25515573226546223
# no significant difference in CT for ('physicalSciences', 'biologicalSciences'), t-value = -0.7859052479933759, p-value = 0.43433482381600685
# no significant difference in CP for ('physicalSciences', 'biologicalSciences'), t-value = 0.5273938864178029, p-value = 0.5994364439009838
# no significant difference in CN for ('physicalSciences', 'biologicalSciences'), t-value = -0.27069223198941267, p-value = 0.7873520344242574
# significant different in MLS for ('physicalSciences', 'biologicalSciences'), t-value = 2.2698266337055637, p-value = 0.026015821347022045
# significant different in MLT for ('physicalSciences', 'biologicalSciences'), t-value = 2.4327782149419144, p-value = 0.01730372168871652
# significant different in MLC for ('physicalSciences', 'biologicalSciences'), t-value = 2.931504928875844, p-value = 0.004439152959960082
# no significant difference in C_S for ('physicalSciences', 'biologicalSciences'), t-value = -0.33511896514949874, p-value = 0.7384466108982399
# no significant difference in VP_T for ('physicalSciences', 'biologicalSciences'), t-value = 0.2847767884851418, p-value = 0.776579673883669
# no significant difference in C_T for ('physicalSciences', 'biologicalSciences'), t-value = -0.1987523522967484, p-value = 0.8429803261319061
# no significant difference in DC_C for ('physicalSciences', 'biologicalSciences'), t-value = -1.315205407900225, p-value = 0.19234406349447272
# no significant difference in DC_T for ('physicalSciences', 'biologicalSciences'), t-value = -0.7011785669008962, p-value = 0.48530529561646074
# no significant difference in T_S for ('physicalSciences', 'biologicalSciences'), t-value = 0.30494349352455197, p-value = 0.7612319313890656
# no significant difference in CT_T for ('physicalSciences', 'biologicalSciences'), t-value = -0.564846428480252, p-value = 0.5738201836050421
# no significant difference in CP_T for ('physicalSciences', 'biologicalSciences'), t-value = 1.5943038473197333, p-value = 0.11496476693289381
# weak difference in CP_C for ('physicalSciences', 'biologicalSciences'), t-value = 1.7566108244513705, p-value = 0.08295981910581403
# no significant difference in CN_T for ('physicalSciences', 'biologicalSciences'), t-value = 1.5906503633868323, p-value = 0.11578586185935631
# significant different in CN_C for ('physicalSciences', 'biologicalSciences'), t-value = 2.0741560048247893, p-value = 0.04140736335714493
# no significant difference in W for ('physicalSciences', 'socialSciences'), t-value = 0.03256927774075837, p-value = 0.9741163654329683
# no significant difference in S for ('physicalSciences', 'socialSciences'), t-value = -1.6513037648207978, p-value = 0.10342731077975098
# significant different in VP for ('physicalSciences', 'socialSciences'), t-value = -2.378851843170928, p-value = 0.02026787328745578
# significant different in C for ('physicalSciences', 'socialSciences'), t-value = -2.770204971148107, p-value = 0.007268325280400095
# no significant difference in T for ('physicalSciences', 'socialSciences'), t-value = -1.4951580193682843, p-value = 0.1396395729316829
# significant different in DC for ('physicalSciences', 'socialSciences'), t-value = -2.622391673560361, p-value = 0.010831258769303376
# significant different in CT for ('physicalSciences', 'socialSciences'), t-value = -2.3720006695457583, p-value = 0.0206166403242266
# no significant difference in CP for ('physicalSciences', 'socialSciences'), t-value = -0.14377890732250695, p-value = 0.8861131643107651
# no significant difference in CN for ('physicalSciences', 'socialSciences'), t-value = -0.36412811717070925, p-value = 0.7169263111587107
# no significant difference in MLS for ('physicalSciences', 'socialSciences'), t-value = 1.4887091377300181, p-value = 0.14132693730638024
# no significant difference in MLT for ('physicalSciences', 'socialSciences'), t-value = 1.5419811155874754, p-value = 0.12785956015286928
# significant different in MLC for ('physicalSciences', 'socialSciences'), t-value = 3.6780963749261906, p-value = 0.00047409563272151153
# significant different in C_S for ('physicalSciences', 'socialSciences'), t-value = -2.3713732806480894, p-value = 0.020648844262895236
# no significant difference in VP_T for ('physicalSciences', 'socialSciences'), t-value = -1.4824482600108297, p-value = 0.1429804028956079
# significant different in C_T for ('physicalSciences', 'socialSciences'), t-value = -2.6054930572772133, p-value = 0.01132666377877973
# significant different in DC_C for ('physicalSciences', 'socialSciences'), t-value = -2.871026920318624, p-value = 0.005493904211939175
# significant different in DC_T for ('physicalSciences', 'socialSciences'), t-value = -2.4276859319060216, p-value = 0.017930764436942883
# no significant difference in T_S for ('physicalSciences', 'socialSciences'), t-value = -0.4599247723920445, p-value = 0.6470817845954651
# significant different in CT_T for ('physicalSciences', 'socialSciences'), t-value = -2.1977672024132224, p-value = 0.03147920929032024
# no significant difference in CP_T for ('physicalSciences', 'socialSciences'), t-value = 0.21689443902545646, p-value = 0.8289596743087563
# no significant difference in CP_C for ('physicalSciences', 'socialSciences'), t-value = 1.4303147318454155, p-value = 0.1573440763791164
# no significant difference in CN_T for ('physicalSciences', 'socialSciences'), t-value = 0.4932776190115354, p-value = 0.6234538183789851
# significant different in CN_C for ('physicalSciences', 'socialSciences'), t-value = 2.537707496284773, p-value = 0.013527318795676388
# no significant difference in W for ('biologicalSciences', 'socialSciences'), t-value = 0.12313694667638414, p-value = 0.9023728689367777
# no significant difference in S for ('biologicalSciences', 'socialSciences'), t-value = 0.06832957185942526, p-value = 0.9457298757540824
# no significant difference in VP for ('biologicalSciences', 'socialSciences'), t-value = -1.1071471987112407, p-value = 0.2722491562089003
# significant different in C for ('biologicalSciences', 'socialSciences'), t-value = -2.0545721912183765, p-value = 0.04388327711103739
# no significant difference in T for ('biologicalSciences', 'socialSciences'), t-value = -0.20126441557177982, p-value = 0.8411108238378812
# weak difference in DC for ('biologicalSciences', 'socialSciences'), t-value = -1.9411020043981009, p-value = 0.05651799489157425
# weak difference in CT for ('biologicalSciences', 'socialSciences'), t-value = -1.8313456393292034, p-value = 0.07156268454773775
# no significant difference in CP for ('biologicalSciences', 'socialSciences'), t-value = -0.33521681230659184, p-value = 0.7385246957190199
# no significant difference in CN for ('biologicalSciences', 'socialSciences'), t-value = 0.061620450793712575, p-value = 0.951051317019705
# no significant difference in MLS for ('biologicalSciences', 'socialSciences'), t-value = -0.5636111780614369, p-value = 0.5749288289280319
# no significant difference in MLT for ('biologicalSciences', 'socialSciences'), t-value = -0.4356309549602216, p-value = 0.6645259618127854
# weak difference in MLC for ('biologicalSciences', 'socialSciences'), t-value = 1.9308835307623446, p-value = 0.05779466810988924
# significant different in C_S for ('biologicalSciences', 'socialSciences'), t-value = -2.2726233965172105, p-value = 0.026311972757263505
# no significant difference in VP_T for ('biologicalSciences', 'socialSciences'), t-value = -1.1517246581359208, p-value = 0.2535892772181034
# significant different in C_T for ('biologicalSciences', 'socialSciences'), t-value = -2.250532718517714, p-value = 0.027752801592604813
# weak difference in DC_C for ('biologicalSciences', 'socialSciences'), t-value = -1.7702595192544417, p-value = 0.08130218094134639
# weak difference in DC_T for ('biologicalSciences', 'socialSciences'), t-value = -1.7812771583175142, p-value = 0.07946832017404437
# no significant difference in T_S for ('biologicalSciences', 'socialSciences'), t-value = -0.9995721182794297, p-value = 0.32116836364845003
# no significant difference in CT_T for ('biologicalSciences', 'socialSciences'), t-value = -1.3899244800291708, p-value = 0.1692222208056176
# no significant difference in CP_T for ('biologicalSciences', 'socialSciences'), t-value = -0.7957477910423458, p-value = 0.4290314039522468
# no significant difference in CP_C for ('biologicalSciences', 'socialSciences'), t-value = 0.16435401148965623, p-value = 0.8699547750373536
# no significant difference in CN_T for ('biologicalSciences', 'socialSciences'), t-value = -0.7491558413724095, p-value = 0.4564251174976166
# no significant difference in CN_C for ('biologicalSciences', 'socialSciences'), t-value = 1.1468402101760524, p-value = 0.25558831606278776
