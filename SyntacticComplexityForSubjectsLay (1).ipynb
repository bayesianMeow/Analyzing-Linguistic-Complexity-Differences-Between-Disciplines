# %%
file_path = "/content/drive/My Drive/Colab Notebooks/14-Indices (2).txt"
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
import itertools

W = {"Lay Summary" : {}, "Technical Summary": {} }
S = {"Lay Summary" : {}, "Technical Summary": {} }
VP = {"Lay Summary" : {}, "Technical Summary": {} }
C = {"Lay Summary" : {}, "Technical Summary": {} }
T = {"Lay Summary" : {}, "Technical Summary": {} }
DC = {"Lay Summary" : {}, "Technical Summary": {} }
CT = {"Lay Summary" : {}, "Technical Summary": {} }
CP = {"Lay Summary" : {}, "Technical Summary": {} }
CN = {"Lay Summary" : {}, "Technical Summary": {} }
MLS = {"Lay Summary" : {}, "Technical Summary": {} }
MLT = {"Lay Summary" : {}, "Technical Summary": {} }
MLC = {"Lay Summary" : {}, "Technical Summary": {} }
C_S = {"Lay Summary" : {}, "Technical Summary": {} }
VP_T = {"Lay Summary" : {}, "Technical Summary": {} }
C_T = {"Lay Summary" : {}, "Technical Summary": {} }
DC_C = {"Lay Summary" : {}, "Technical Summary": {} }
DC_T = {"Lay Summary" : {}, "Technical Summary": {} }
T_S = {"Lay Summary" : {}, "Technical Summary": {} }
CT_T = {"Lay Summary" : {}, "Technical Summary": {} }
CP_T = {"Lay Summary" : {}, "Technical Summary": {} }
CP_C = {"Lay Summary" : {}, "Technical Summary": {} }
CN_T = {"Lay Summary" : {}, "Technical Summary": {} }
CN_C = {"Lay Summary" : {}, "Technical Summary": {} }

subjectLabels = {}

MasterDictionary2 = {"W" : W, "S" : S, "VP": VP, "C": C, "T": T, "DC" : DC, "CT" : CT, "CP" :CP, "CN" :CN, "MLS" : MLS, "MLT" : MLT, "MLC" : MLC, "C_S" : C_S, "VP_T" : VP_T, "C_T" : C_T, "DC_C" : DC_C, "DC_T" : DC_T, "T_S" : T_S, "CT_T" : CT_T, "CP_T" : CP_T, "CP_C" : CP_C, "CN_T" : CN_T, "CN_C" : CN_C}
Subjects = {}

lineNum = 0
laySummaryCount = 0
techSummaryCount = 0

with open(file_path, "r") as file:

    for line in file:

        #Document all the subjects of the summaries
        lineNum += 1
        if lineNum % 3 == 1:
          subject = line.strip().lower()
          if subject in Subjects.keys():
            Subjects[subject] += 1
          else:
            Subjects[subject] = 1
        else:
          # Remove trailing newline and whitespace
          preValues = [val.strip() for val in line.strip().split(",")]
          values = []
          for value in preValues:
            values.append(float(value))

          if lineNum % 3 == 2:

            laySummaryCount += 1
            subjectLabels[laySummaryCount] = subject.strip().lower()

          else:

            techSummaryCount += 1

          for value in values:

            if lineNum % 3 == 2:

              W["Lay Summary"][laySummaryCount] = values[0]
              S["Lay Summary"][laySummaryCount] = values[1]
              VP["Lay Summary"][laySummaryCount] = values[2]
              C["Lay Summary"][laySummaryCount] = values[3]
              T["Lay Summary"][laySummaryCount] = values[4]
              DC["Lay Summary"][laySummaryCount] = values[5]
              CT["Lay Summary"][laySummaryCount] = values[6]
              CP["Lay Summary"][laySummaryCount] = values[7]
              CN["Lay Summary"][laySummaryCount] = values[8]
              MLS["Lay Summary"][laySummaryCount] = values[9]
              MLT["Lay Summary"][laySummaryCount] = values[10]
              MLC["Lay Summary"][laySummaryCount] = values[11]
              C_S["Lay Summary"][laySummaryCount] = values[12]
              VP_T["Lay Summary"][laySummaryCount] = values[13]
              C_T["Lay Summary"][laySummaryCount] = values[14]
              DC_C["Lay Summary"][laySummaryCount] = values[15]
              DC_T["Lay Summary"][laySummaryCount] = values[16]
              T_S["Lay Summary"][laySummaryCount] = values[17]
              CT_T["Lay Summary"][laySummaryCount] = values[18]
              CP_T["Lay Summary"][laySummaryCount] = values[19]
              CP_C["Lay Summary"][laySummaryCount] = values[20]
              CN_T["Lay Summary"][laySummaryCount] = values[21]
              CN_C["Lay Summary"][laySummaryCount] = values[22]
            else:
              W["Technical Summary"][techSummaryCount] = values[0]
              S["Technical Summary"][techSummaryCount] = values[1]
              VP["Technical Summary"][techSummaryCount] = values[2]
              C["Technical Summary"][techSummaryCount] = values[3]
              T["Technical Summary"][techSummaryCount] = values[4]
              DC["Technical Summary"][techSummaryCount] = values[5]
              CT["Technical Summary"][techSummaryCount] = values[6]
              CP["Technical Summary"][techSummaryCount] = values[7]
              CN["Technical Summary"][techSummaryCount] = values[8]
              MLS["Technical Summary"][techSummaryCount] = values[9]
              MLT["Technical Summary"][techSummaryCount] = values[10]
              MLC["Technical Summary"][techSummaryCount] = values[11]
              C_S["Technical Summary"][techSummaryCount] = values[12]
              VP_T["Technical Summary"][techSummaryCount] = values[13]
              C_T["Technical Summary"][techSummaryCount] = values[14]
              DC_C["Technical Summary"][techSummaryCount] = values[15]
              DC_T["Technical Summary"][techSummaryCount] = values[16]
              T_S["Technical Summary"][techSummaryCount] = values[17]
              CT_T["Technical Summary"][techSummaryCount] = values[18]
              CP_T["Technical Summary"][techSummaryCount] = values[19]
              CP_C["Technical Summary"][techSummaryCount] = values[20]
              CN_T["Technical Summary"][techSummaryCount] = values[21]
              CN_C["Technical Summary"][techSummaryCount] = values[22]


physicalSciences = ['environmental sciences', 'earth, atmospheric, and planetary sciences', 'applied physical sciences', 'computer sciences','applied mathematics','engineering','chemistry','statistics','sustainability science','physics','astronomy']
biologicalSciences = ['biophysics and computational biology','immunology and inflammation','neuroscience', 'genetics', 'ecology', 'medical sciences','evolution','plant biology','agricultural sciences','applied biological sciences','biochemistry','developmental biology','systems biology','microbiology','pharmacology','cell biology','physiology','population biology']
socialSciences = ['economic sciences','psychological and cognitive sciences','demography','political sciences','social sciences','anthropology','']

umbrellas = {'physicalSciences':physicalSciences,'biologicalSciences':biologicalSciences,'socialSciences': socialSciences}

#physCount = 0
#bioCount = 0
#socCount = 0

#for subject in Subjects.keys():

  #if subject in physicalSciences:

    #physCount += Subjects[subject]

  #elif subject in biologicalSciences:

    #bioCount += Subjects[subject]

  #elif subject in socialSciences:

    #socCount += Subjects[subject]

#print(f"There are {physCount} in physical")
#print(f"There are {bioCount} in physical")
#print(f"There are {socCount} in social")

Measures = [W,S,VP,C,T,DC,CT,CP,CN,MLS,MLT,MLC,C_S,VP_T,C_T,DC_C,DC_T,T_S,CT_T,CP_T,CP_C,CN_T,CN_C]

measure_names = [
    "W", "S", "VP", "C", "T", "DC", "CT", "CP", "CN",
    "MLS", "MLT", "MLC", "C_S", "VP_T", "C_T", "DC_C", "DC_T",
    "T_S", "CT_T", "CP_T", "CP_C", "CN_T", "CN_C"
]


results3 = {}

for pair in itertools.combinations(umbrellas.keys(),2):
  results3[pair] = {}

for pair in itertools.combinations(umbrellas.keys(), 2):

  subjOne = pair[0]
  subjTwo = pair[1]

  for name, measure in zip(measure_names, Measures):

    subOneValues = []
    subTwoValues = []


    for i in range(1,300):

      if subjectLabels[i] in umbrellas[subjOne]:
        subOneValues.append(measure["Lay Summary"][i])

      elif subjectLabels[i] in umbrellas[subjTwo]:

        subTwoValues.append(measure["Lay Summary"][i])

    t_stat, p_val = ttest_ind(subOneValues, subTwoValues)

    results3[pair][name] = {'t': t_stat, 'p': p_val}

    print(f"{name} for {pair}")

    plt.hist(subOneValues, bins = 30, color = 'skyblue', alpha = 0.5, label = "lay")

    plt.hist(subTwoValues, bins = 30, color = 'red', alpha = 0.5, label = "tech")

    plt.show()

    plt.ecdf(subOneValues, color = 'skyblue', alpha = 0.5, label = "lay")

    plt.ecdf(subTwoValues, color = 'red', alpha = 0.5, label = "tech")

    plt.show()

for pair in results3.keys():

  for measure in measure_names:
    if results3[pair][measure]['p']<0.05:
      print(f"significant different in {measure} for {pair}, t-value = {results3[pair][measure]['t']}, p-value = {results3[pair][measure]['p']} ")
    elif results3[pair][measure]['p']<0.1:
      print(f"weak difference in {measure} for {pair}, t-value = {results3[pair][measure]['t']}, p-value = {results3[pair][measure]['p']} ")
    elif results3[pair][measure]['p']>=0.1:
      print(f"no significant difference in {measure} for {pair}, t-value = {results3[pair][measure]['t']}, p-value = {results3[pair][measure]['p']} ")
# Out:
# Mounted at /content/drive
# W for ('physicalSciences', 'biologicalSciences')
# S for ('physicalSciences', 'biologicalSciences')
# VP for ('physicalSciences', 'biologicalSciences')
# C for ('physicalSciences', 'biologicalSciences')
# T for ('physicalSciences', 'biologicalSciences')
# DC for ('physicalSciences', 'biologicalSciences')
# CT for ('physicalSciences', 'biologicalSciences')
# CP for ('physicalSciences', 'biologicalSciences')
# CN for ('physicalSciences', 'biologicalSciences')
# MLS for ('physicalSciences', 'biologicalSciences')
# MLT for ('physicalSciences', 'biologicalSciences')
# MLC for ('physicalSciences', 'biologicalSciences')
# C_S for ('physicalSciences', 'biologicalSciences')
# VP_T for ('physicalSciences', 'biologicalSciences')
# C_T for ('physicalSciences', 'biologicalSciences')
# DC_C for ('physicalSciences', 'biologicalSciences')
# DC_T for ('physicalSciences', 'biologicalSciences')
# T_S for ('physicalSciences', 'biologicalSciences')
# CT_T for ('physicalSciences', 'biologicalSciences')
# CP_T for ('physicalSciences', 'biologicalSciences')
# CP_C for ('physicalSciences', 'biologicalSciences')
# CN_T for ('physicalSciences', 'biologicalSciences')
# CN_C for ('physicalSciences', 'biologicalSciences')
# W for ('physicalSciences', 'socialSciences')
# S for ('physicalSciences', 'socialSciences')
# VP for ('physicalSciences', 'socialSciences')
# C for ('physicalSciences', 'socialSciences')
# T for ('physicalSciences', 'socialSciences')
# DC for ('physicalSciences', 'socialSciences')
# CT for ('physicalSciences', 'socialSciences')
# CP for ('physicalSciences', 'socialSciences')
# CN for ('physicalSciences', 'socialSciences')
# MLS for ('physicalSciences', 'socialSciences')
# MLT for ('physicalSciences', 'socialSciences')
# MLC for ('physicalSciences', 'socialSciences')
# C_S for ('physicalSciences', 'socialSciences')
# VP_T for ('physicalSciences', 'socialSciences')
# C_T for ('physicalSciences', 'socialSciences')
# DC_C for ('physicalSciences', 'socialSciences')
# DC_T for ('physicalSciences', 'socialSciences')
# T_S for ('physicalSciences', 'socialSciences')
# CT_T for ('physicalSciences', 'socialSciences')
# CP_T for ('physicalSciences', 'socialSciences')
# CP_C for ('physicalSciences', 'socialSciences')
# CN_T for ('physicalSciences', 'socialSciences')
# CN_C for ('physicalSciences', 'socialSciences')
# W for ('biologicalSciences', 'socialSciences')
# S for ('biologicalSciences', 'socialSciences')
# VP for ('biologicalSciences', 'socialSciences')
# C for ('biologicalSciences', 'socialSciences')
# T for ('biologicalSciences', 'socialSciences')
# DC for ('biologicalSciences', 'socialSciences')
# CT for ('biologicalSciences', 'socialSciences')
# CP for ('biologicalSciences', 'socialSciences')
# CN for ('biologicalSciences', 'socialSciences')
# MLS for ('biologicalSciences', 'socialSciences')
# MLT for ('biologicalSciences', 'socialSciences')
# MLC for ('biologicalSciences', 'socialSciences')
# C_S for ('biologicalSciences', 'socialSciences')
# VP_T for ('biologicalSciences', 'socialSciences')
# C_T for ('biologicalSciences', 'socialSciences')
# DC_C for ('biologicalSciences', 'socialSciences')
# DC_T for ('biologicalSciences', 'socialSciences')
# T_S for ('biologicalSciences', 'socialSciences')
# CT_T for ('biologicalSciences', 'socialSciences')
# CP_T for ('biologicalSciences', 'socialSciences')
# CP_C for ('biologicalSciences', 'socialSciences')
# CN_T for ('biologicalSciences', 'socialSciences')
# CN_C for ('biologicalSciences', 'socialSciences')
# no significant difference in W for ('physicalSciences', 'biologicalSciences'), t-value = 0.07639729230630174, p-value = 0.9391694365583434
# significant different in S for ('physicalSciences', 'biologicalSciences'), t-value = -2.4415165547144952, p-value = 0.015380829349145435
# no significant difference in VP for ('physicalSciences', 'biologicalSciences'), t-value = -1.5524887810157522, p-value = 0.12192021751648213
# significant different in C for ('physicalSciences', 'biologicalSciences'), t-value = -2.4032078674159956, p-value = 0.017045073496919333
# significant different in T for ('physicalSciences', 'biologicalSciences'), t-value = -2.0928781873329436, p-value = 0.03745623704155826
# no significant difference in DC for ('physicalSciences', 'biologicalSciences'), t-value = -1.609245138511742, p-value = 0.10893442079055267
# no significant difference in CT for ('physicalSciences', 'biologicalSciences'), t-value = -1.5049117840778763, p-value = 0.13371876392476606
# no significant difference in CP for ('physicalSciences', 'biologicalSciences'), t-value = 0.5198742641068058, p-value = 0.6036512018820919
# no significant difference in CN for ('physicalSciences', 'biologicalSciences'), t-value = -0.12110715848982583, p-value = 0.9037118947828768
# significant different in MLS for ('physicalSciences', 'biologicalSciences'), t-value = 2.9844470208162317, p-value = 0.003147603298978449
# significant different in MLT for ('physicalSciences', 'biologicalSciences'), t-value = 3.024899806125745, p-value = 0.002769719926095698
# significant different in MLC for ('physicalSciences', 'biologicalSciences'), t-value = 3.786521490586789, p-value = 0.00019501188418289526
# no significant difference in C_S for ('physicalSciences', 'biologicalSciences'), t-value = -0.9040445424616959, p-value = 0.36691770465454776
# no significant difference in VP_T for ('physicalSciences', 'biologicalSciences'), t-value = 0.2216758661307817, p-value = 0.82476291114392
# no significant difference in C_T for ('physicalSciences', 'biologicalSciences'), t-value = -0.8532856454886897, p-value = 0.3943886694456369
# no significant difference in DC_C for ('physicalSciences', 'biologicalSciences'), t-value = -1.5023742337761878, p-value = 0.13437219330387348
# no significant difference in DC_T for ('physicalSciences', 'biologicalSciences'), t-value = -1.013236714225529, p-value = 0.31201181690816443
# no significant difference in T_S for ('physicalSciences', 'biologicalSciences'), t-value = -0.012792811896137964, p-value = 0.9898041809159708
# no significant difference in CT_T for ('physicalSciences', 'biologicalSciences'), t-value = -1.0359363741648235, p-value = 0.30131975701792896
# no significant difference in CP_T for ('physicalSciences', 'biologicalSciences'), t-value = 1.6116230533649454, p-value = 0.10841536961465799
# significant different in CP_C for ('physicalSciences', 'biologicalSciences'), t-value = 2.1402586663179197, p-value = 0.03338637552220031
# significant different in CN_T for ('physicalSciences', 'biologicalSciences'), t-value = 2.201433723759467, p-value = 0.028699282745616776
# significant different in CN_C for ('physicalSciences', 'biologicalSciences'), t-value = 2.9622947797612253, p-value = 0.003374043863128899
# no significant difference in W for ('physicalSciences', 'socialSciences'), t-value = 0.09041187184207902, p-value = 0.9280864388020688
# no significant difference in S for ('physicalSciences', 'socialSciences'), t-value = -1.6189869638427, p-value = 0.10765349264055493
# significant different in VP for ('physicalSciences', 'socialSciences'), t-value = -2.6086948385404574, p-value = 0.010054559279863406
# significant different in C for ('physicalSciences', 'socialSciences'), t-value = -3.3128784455219624, p-value = 0.0011696419394070588
# no significant difference in T for ('physicalSciences', 'socialSciences'), t-value = -1.5681134292203307, p-value = 0.1190648383289557
# significant different in DC for ('physicalSciences', 'socialSciences'), t-value = -3.151920370198757, p-value = 0.001976354627263146
# significant different in CT for ('physicalSciences', 'socialSciences'), t-value = -2.8803275495276006, p-value = 0.0045843186873252
# no significant difference in CP for ('physicalSciences', 'socialSciences'), t-value = -0.004533612349206552, p-value = 0.9963890315318309
# no significant difference in CN for ('physicalSciences', 'socialSciences'), t-value = -0.4922167001386309, p-value = 0.6233209732785263
# no significant difference in MLS for ('physicalSciences', 'socialSciences'), t-value = 1.4050616926178703, p-value = 0.1621715804452076
# no significant difference in MLT for ('physicalSciences', 'socialSciences'), t-value = 1.5451483201128793, p-value = 0.12452056936221599
# significant different in MLC for ('physicalSciences', 'socialSciences'), t-value = 4.014048131281417, p-value = 9.594234544758954e-05
# significant different in C_S for ('physicalSciences', 'socialSciences'), t-value = -2.712370164942351, p-value = 0.00750049628356517
# no significant difference in VP_T for ('physicalSciences', 'socialSciences'), t-value = -1.4983303777701342, p-value = 0.1362516824299086
# significant different in C_T for ('physicalSciences', 'socialSciences'), t-value = -2.7707658648536726, p-value = 0.006336008439017184
# significant different in DC_C for ('physicalSciences', 'socialSciences'), t-value = -3.1308955590856513, p-value = 0.0021135331897374236
# significant different in DC_T for ('physicalSciences', 'socialSciences'), t-value = -2.727928505780254, p-value = 0.007172639438141621
# no significant difference in T_S for ('physicalSciences', 'socialSciences'), t-value = -0.7067830813754038, p-value = 0.4808513816729554
# significant different in CT_T for ('physicalSciences', 'socialSciences'), t-value = -2.4717490793155767, p-value = 0.014618903945605192
# no significant difference in CP_T for ('physicalSciences', 'socialSciences'), t-value = 0.3577447770164218, p-value = 0.7210617990163046
# no significant difference in CP_C for ('physicalSciences', 'socialSciences'), t-value = 1.6333198147431174, p-value = 0.10460161844872434
# no significant difference in CN_T for ('physicalSciences', 'socialSciences'), t-value = 0.5033067791596298, p-value = 0.6155229853531154
# significant different in CN_C for ('physicalSciences', 'socialSciences'), t-value = 2.673897649690535, p-value = 0.008370298587383524
# no significant difference in W for ('biologicalSciences', 'socialSciences'), t-value = 0.030227592040529605, p-value = 0.9759130721750395
# no significant difference in S for ('biologicalSciences', 'socialSciences'), t-value = 0.0560251982763981, p-value = 0.9553728131301789
# weak difference in VP for ('biologicalSciences', 'socialSciences'), t-value = -1.7651734633389302, p-value = 0.07892830039460182
# weak difference in C for ('biologicalSciences', 'socialSciences'), t-value = -1.8750701134089558, p-value = 0.06211398285396818
# no significant difference in T for ('biologicalSciences', 'socialSciences'), t-value = -0.08634291257054719, p-value = 0.9312727159686699
# significant different in DC for ('biologicalSciences', 'socialSciences'), t-value = -2.324669494978772, p-value = 0.02100545832486146
# significant different in CT for ('biologicalSciences', 'socialSciences'), t-value = -2.2896918033930036, p-value = 0.022991757505718177
# no significant difference in CP for ('biologicalSciences', 'socialSciences'), t-value = -0.48363562297059837, p-value = 0.6291277035931686
# no significant difference in CN for ('biologicalSciences', 'socialSciences'), t-value = -0.4527654874776832, p-value = 0.6511658312969717
# no significant difference in MLS for ('biologicalSciences', 'socialSciences'), t-value = -1.0270085333614642, p-value = 0.30554944098926284
# no significant difference in MLT for ('biologicalSciences', 'socialSciences'), t-value = -0.8589657764368984, p-value = 0.39129859829139335
# weak difference in MLC for ('biologicalSciences', 'socialSciences'), t-value = 1.772099941099542, p-value = 0.07776837193404072
# significant different in C_S for ('biologicalSciences', 'socialSciences'), t-value = -2.689807489234068, p-value = 0.007700089154173333
# weak difference in VP_T for ('biologicalSciences', 'socialSciences'), t-value = -1.900956016418572, p-value = 0.058620790216720585
# significant different in C_T for ('biologicalSciences', 'socialSciences'), t-value = -2.3424463779392184, p-value = 0.020054898582754666
# significant different in DC_C for ('biologicalSciences', 'socialSciences'), t-value = -2.3719905479564156, p-value = 0.018558582424682196
# significant different in DC_T for ('biologicalSciences', 'socialSciences'), t-value = -2.370306608254367, p-value = 0.0186411478673349
# no significant difference in T_S for ('biologicalSciences', 'socialSciences'), t-value = -0.7535999036892657, p-value = 0.45189893210969867
# significant different in CT_T for ('biologicalSciences', 'socialSciences'), t-value = -2.078437225745928, p-value = 0.03883415966882535
# no significant difference in CP_T for ('biologicalSciences', 'socialSciences'), t-value = -1.0645590910069846, p-value = 0.288247829644042
# no significant difference in CP_C for ('biologicalSciences', 'socialSciences'), t-value = -0.04745100595159422, p-value = 0.9621970212656263
# no significant difference in CN_T for ('biologicalSciences', 'socialSciences'), t-value = -1.3299297897352584, p-value = 0.1849248411797372
# no significant difference in CN_C for ('biologicalSciences', 'socialSciences'), t-value = 0.7333561536481478, p-value = 0.4641255290735662
